# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Practical numpy example

# %% [markdown]
# ### So in machine learning whatever data you have , you have to convert it into numpy array and then you can apply machine learning algorithms on it to find the patterns in the data.

# %% [markdown]
# <img src="../images/panda.png" />

# %%
# Turn an image into a numpy array
from matplotlib.image import imread

# %%
panda = imread("../images/numpy-panda.png")
panda
# Out:
# array([[[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        ...,
#
#        [[0.13333334, 0.07450981, 0.05490196],
# ...

# %%
panda.shape
# Out:
# (2330, 3500, 3)

# %%
panda.size
# Out:
# 24465000

# %%
panda.ndim
# Out:
# 3

# %%
plt.imshow(panda)

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
random_array = np.random.random(size=(2330, 3500, 3))
random_array.shape
# Out:
# (2330, 3500, 3)

# %%
plt.imshow(random_array)

# %%
random_array.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 random_array.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
random_array[:10]
# Out:
# array([[[0.47913107, 0.25770225, 0.83046518],
#         [0.19182555, 0.60100099, 0.64315912],
#         [0.18967493, 0.70987881, 0.34122166],
#         ...,
#         [0.69640381, 0.388643  , 0.93319802],
#         [0.72737497, 0.19009552, 0.31698117],
#         [0.13613572, 0.40306149, 0.7235079 ]],
#
#        [[0.42152681, 0.02746643, 0.70917446],
#         [0.82657098, 0.54829373, 0.8330776 ],
#         [0.05686728, 0.31899856, 0.01088715],
#         ...,
#         [0.64910137, 0.29579024, 0.55798197],
#         [0.62577191, 0.5820629 , 0.77733817],
#         [0.23358007, 0.10906541, 0.79306174]],
#
#        [[0.10541063, 0.91180811, 0.54142922],
#         [0.79595827, 0.27544708, 0.48624382],
#         [0.42554265, 0.3180987 , 0.85303829],
#         ...,
#         [0.06625152, 0.24159975, 0.53869926],
#         [0.31816628, 0.84145316, 0.42262414],
#         [0.07153113, 0.18227346, 0.60482863]],
#
#        ...,
#
#        [[0.46090067, 0.03862679, 0.15711233],
# ...

# %%
random_array[0:0:0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 random_array[0:0:0]
#
# ValueError: slice step cannot be zero

# %%
random_array[:2, :2, :2]
# Out:
# array([[[0.47913107, 0.25770225],
#         [0.19182555, 0.60100099]],
#
#        [[0.42152681, 0.02746643],
#         [0.82657098, 0.54829373]]])

# %%
panda.size
# Out:
# 24465000

# %%
random_array.size
# Out:
# 24465000

# %%
dog_photo = imread("../images/dog-photo-1.jpeg");
dog_photo.shape
# Out:
# (432, 575, 4)

# %%
plt.imshow(dog_photo)

# %%
plt.imshow(dog_photo + .20)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### So the key take way is this - image convert to number and let's say for tree in one photo (when it convert to number) is similar the tree in another photo (when it converts to number because the number difference will be very small) so we can say that the tree is similar in both the photos. Because machine learning algorithm will learn from one photo number and then if it find the same number in different photo then it'll consider it as similar.
